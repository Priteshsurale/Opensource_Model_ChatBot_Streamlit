# %%
from langchain_ollama import OllamaEmbeddings

# %%
embedding = OllamaEmbeddings(model='llama3.2')
embedding
# Out:
# OllamaEmbeddings(model='llama3.2', base_url=None, client_kwargs={})

# %%
r1= embedding.embed_documents([
    'my name is prtesh surale',
    'i am a software devloper'
])

# %%
len(r1[0])
# Out:
# 3072

# %%
embedding.embed_query('why sky is blue')
# Out:
# [-0.0148559315,
#  0.0035767423,
#  0.03476998,
#  -0.013892965,
#  0.0039402572,
#  -0.007727654,
#  0.002129478,
#  0.004302638,
#  0.011800532,
#  -0.0073483717,
#  -0.00046870217,
#  0.028906707,
#  0.021365458,
#  0.029101335,
#  -0.0128523465,
#  0.020619884,
#  0.015138985,
#  -0.006563029,
#  -0.0074046846,
#  -0.010977082,
#  -0.012726056,
#  -0.008123338,
#  0.004037788,
#  -0.006442788,
#  -0.00086770824,
#  -0.007912243,
#  0.016923346,
#  -0.0117342165,
#  0.023506036,
#  0.0082278205,
#  0.010337612,
#  0.037422083,
#  -0.024794478,
#  0.008471825,
#  0.031818707,
#  0.008760198,
#  0.008535497,
#  0.02778088,
#  -0.009202366,
#  -0.01548336,
#  -0.0039990484,
#  -0.014135283,
#  -0.0077919555,
#  0.0140258055,
#  -0.027045073,
#  -0.015274395,
#  0.018149633,
#  0.002498041,
#  -0.0006970547,
#  -0.011297884,
#  0.005267099,
#  0.0015040586,
#  0.0023647605,
#  0.009110679,
#  0.024435842,
#  -0.006711351,
#  0.017722394,
#  -0.040465094,
#  0.005205175,
# ...
